# %%
# importing the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# turning off warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# importing the sales data
df = pd.read_csv("data/data.csv")
df.head(5)
# Out:
#    SELL_ID  SELL_CATEGORY ITEM_NAME CALENDAR_DATE  PRICE  QUANTITY  YEAR  \
# 0     1070              0       TEA       1/13/12   15.5       100  2012
# 1     1070              0       TEA       1/13/13   15.5        70  2013
# 2     1070              0       TEA       1/13/14   15.5       104  2014
# 3     1070              0       TEA       1/13/15   14.0       116  2015
# 4     1070              0       TEA       1/14/12   15.5        74  2012
#
#       HOLIDAY  IS_WEEKEND  IS_SCHOOLBREAK  AVERAGE_TEMPERATURE  IS_OUTDOOR
# 0  No Holiday           0               0                 26.6           0
# 1  No Holiday           1               0                 30.2           0
# 2  No Holiday           0               0                 28.4           0
# 3  No Holiday           0               0                 28.4           0
# 4  No Holiday           1               0                 23.0           0

# %% [markdown]
# ### Removing Effects

# %% [markdown]
# Now this df consists of transactions made in all days but we know that  on holidays,weekend and school breaks the price of the food items change, so we are going to remove transactions made on those dates to remove the effect due to the holidays,weekend and school breaks so that we can determine the typical price of the product on the usual day

# %%
# removing transactions made on Holidays, Week-ends, School breaks
df_filtered = df[(df['HOLIDAY'] == "No Holiday") & (df['IS_SCHOOLBREAK'] == 0) & (df['IS_WEEKEND'] == 0)]

# %% [markdown]
# #### 1. Food items

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create the count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='ITEM_NAME', data=df, palette='viridis')

# Add titles and labels
plt.title('Item Count Plot')
plt.xlabel('Item Name')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# We can see that most of the people buy tea followed by coke, juice and coffee

# %% [markdown]
# #### 2. Distribution of Price

# %%
# Create subplots with two plots side by side
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Plot the first Kernel Density plot
sns.kdeplot(df['PRICE'], shade=True, color='b', ax=axes[0])

# Add titles and labels to the first plot
axes[0].set_title('Kernel Density Plot of Price (Original')
axes[0].set_xlabel('Price')
axes[0].set_ylabel('Density')

# Plot the second Kernel Density plot
sns.kdeplot(df_filtered['PRICE'], shade=True, color='b', ax=axes[1])

# Add titles and labels to the second plot
axes[1].set_title('Kernel Density Plot of Price (Filtered)')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Density')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# From the KDE plot we can clearly see that there are more than single peaks which means it's bi-modal distribution

# %% [markdown]
# #### 3. Price  vs Quantity

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(9, 4))
sns.scatterplot(x='PRICE', y='QUANTITY', data=df)

# Add titles and labels
plt.title('Scatter Plot of Price vs Quantity')
plt.xlabel('Price')
plt.ylabel('Quantity')

# Show the plot
plt.show()

# %% [markdown]
# We can clearly see that there are two groups in the scatter plot

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(9, 4))
sns.scatterplot(x='PRICE', y='QUANTITY', hue="ITEM_NAME",data=df)

# Add titles and labels
plt.title('Scatter Plot of Price vs Quantity')
plt.xlabel('Price')
plt.ylabel('Quantity')

# Show the plot
plt.show()

# %% [markdown]
# #### 4. Pair Plot

# %%
# Create the count plot with increased size
plt.figure(figsize=(12, 9))
sns.pairplot(df[["PRICE","QUANTITY","ITEM_NAME"]],hue="ITEM_NAME",plot_kws={'alpha':0.1})
plt.show()

# %% [markdown]
# We can see the group in the top right corner of the scatter plot is teas

# %% [markdown]
# #### 1. Food items

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Create the count plot
plt.figure(figsize=(9, 4))
sns.countplot(x='ITEM_NAME', data=df_filtered, palette='viridis')

# Add titles and labels
plt.title('Item Count Plot')
plt.xlabel('Item Name')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# #### 2. Price

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with two plots side by side
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Plot the first Kernel Density plot
sns.kdeplot(df['PRICE'], shade=True, color='b', ax=axes[0])

# Add titles and labels to the first plot
axes[0].set_title('Kernel Density Plot of Price (Original)')
axes[0].set_xlabel('Price')
axes[0].set_ylabel('Density')

# Plot the second Kernel Density plot
sns.kdeplot(df_filtered['PRICE'], shade=True, color='b', ax=axes[1])

# Add titles and labels to the second plot
axes[1].set_title('Kernel Density Plot of Price (Filtered)')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Density')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# #### 3. Price vs Quantity

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots with two plots side by side
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Plot the first scatter plot
sns.scatterplot(x='PRICE', y='QUANTITY', data=df, ax=axes[0])

# Add titles and labels to the first plot
axes[0].set_title('Scatter Plot of Price vs Quantity (Original)')
axes[0].set_xlabel('Price')
axes[0].set_ylabel('Quantity')

# Plot the second scatter plot
sns.scatterplot(x='PRICE', y='QUANTITY', data=df_filtered, ax=axes[1])

# Add titles and labels to the second plot
axes[1].set_title('Scatter Plot of Price vs Quantity (Filtered)')
axes[1].set_xlabel('Price')
axes[1].set_ylabel('Quantity')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# #### 4. Pairplot

# %%
# Create the count plot with increased size
plt.figure(figsize=(12, 9))
sns.pairplot(df[["PRICE","QUANTITY","ITEM_NAME"]],hue="ITEM_NAME",plot_kws={'alpha':0.1})
plt.show()

# %%
# Create the count plot with increased size
plt.figure(figsize=(12, 9))
sns.pairplot(df_filtered[["PRICE","QUANTITY","ITEM_NAME"]],hue="ITEM_NAME",plot_kws={'alpha':0.1})
plt.show()
